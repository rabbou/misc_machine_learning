# %% [markdown]
# ### Ruben Abbou
#
# ## Analysis of SOU similarities using TF-IDF and Kmeans

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import json, re, string, math
from math import log
from numpy.linalg import norm
with open('speeches.json', 'r') as f:
    speeches = json.loads(f.read())

# %% [markdown]
# ### (a)

# %%
def clean_and_split(s):
    s = s.lower().replace('-',' ').translate(str.maketrans('','',string.punctuation))
    s = re.sub('(\r\n)+',' ', s)
    s = re.sub(' +',' ',s.strip())
    return s.split(' ')
SOU = []
for speech in speeches:
    SOU.append(clean_and_split(speech['text']))
D = len(SOU)

# vector with every word and a count of zero
sample_vec = {k: 0 for k in [x for sp in SOU for x in sp]}

# %%
# for each speech, make a dictionnary with each word and its count.
vocab = dict(sample_vec)
counts = []
for i in range(D):
    sp_words = dict(sample_vec)
    for word in SOU[i]:
        if sp_words[word] == 0:
            vocab[word] += 1
        sp_words[word] += 1
    counts.append(sp_words)

# %%
# throw out most 20 common words, only keep words that appear more than 50 times
top20 = sorted(vocab.keys(), key=lambda x: vocab[x], reverse=True)[:20]
keys = list(vocab.keys())
for k in keys:
    if vocab[k] < 50 or k in top20:
        del vocab[k]
V = len(vocab)

# %%
# make the tf-idf matrix
tf_idf = np.zeros((D, V))
for i in range(D):
    d = counts[i]
    for j in range(V):
        key = list(vocab.keys())[j]
        ni = d[key]
        den = vocab[key]
        tf_idf[i, j] = ni*log(D/den)

# %% [markdown]
# ### (b)

# %%
presidents = []
years = []
for speech in speeches:
    presidents.append(speech['president'])
    years.append(speech['year'])

# %%
# make similarity matrix
S = np.zeros((D, D))
l = []
def sim(d1, d2):
    return np.dot(d1, d2)/(norm(d1)*norm(d2))
for i in range(D):
    for j in range(D):
        S[i, j] = sim(tf_idf[i], tf_idf[j])
        l.append((S[i, j], i, j))

# %%
same_pres = []
diff_pres = []
# iterate through the upper triangular excluding the diagonal,
# in order to get coordinates for each corresponding pair without repeating pairs
for i in range(D-1):
    for j in range(i+1, D):
        if presidents[i] == presidents[j]:
            same_pres.append((i, j))
        else:
            diff_pres.append((i, j))

# %%
same_pres_sort = [(sim, i, j) for (sim, i, j) in l if (i, j) in same_pres]
same_pres_sort = sorted(same_pres_sort, key = lambda x: x[0], reverse=True)
diff_pres_sort = [(sim, i, j) for (sim, i, j) in l if (i, j) in diff_pres]
diff_pres_sort = sorted(diff_pres_sort, key = lambda x: x[0], reverse=True)

# %%
print("Top 50 most similar pairs of SOUs given by different Presidents:")
for k in range(50):
    sim, i, j = diff_pres_sort[k]
    print("%d:" % (k+1), presidents[i], "(%d) and" % int(years[i])
          , presidents[j], "(%d); " % int(years[j]), "Similarity score: %f" % sim)
# Out:
# Top 50 most similar pairs of SOUs given by different Presidents:
# 1: Dwight D. Eisenhower (1961) and Jimmy Carter (1981);  Similarity score: 0.694960
# 2: Grover Cleveland (1885) and Benjamin Harrison (1889);  Similarity score: 0.676519
# 3: John Tyler (1844) and James K. Polk (1846);  Similarity score: 0.673768
# 4: Dwight D. Eisenhower (1956) and Jimmy Carter (1981);  Similarity score: 0.664240
# 5: William J. Clinton (1994) and Barack Obama (2010);  Similarity score: 0.661743
# 6: Rutherford B. Hayes (1877) and Grover Cleveland (1885);  Similarity score: 0.653579
# 7: Dwight D. Eisenhower (1955) and Jimmy Carter (1981);  Similarity score: 0.653078
# 8: John Tyler (1844) and James K. Polk (1845);  Similarity score: 0.650417
# 9: Andrew Jackson (1836) and Martin Van Buren (1839);  Similarity score: 0.649303
# 10: Theodore Roosevelt (1907) and William Howard Taft (1912);  Similarity score: 0.644658
# 11: William J. Clinton (1998) and George W. Bush (2004);  Similarity score: 0.642952
# 12: George Bush (1992) and William J. Clinton (1994);  Similarity score: 0.642130
# 13: Grover Cleveland (1885) and Benjamin Harrison (1891);  Similarity score: 0.641099
# 14: William J. Clinton (1995) and Barack Obama (2010);  Similarity score: 0.640868
# 15: George Bush (1992) and William J. Clinton (1995);  Similarity score: 0.640204
# 16: William J. Clinton (1993) and Barack Obama (2010);  Similarity score: 0.635353
# 17: Rutherford B. Hayes (1880) and Benjamin Harrison (1889);  Similarity score: 0.632043
# 18: Rutherford B. Hayes (1880) and Grover Cleveland (1885);  Similarity score: 0.631960
# 19: William J. Clinton (1994) and Barack Obama (2011);  Similarity score: 0.630532
# 20: William J. Clinton (1993) and Barack Obama (2011);  Similarity score: 0.629371
# 21: Gerald R. Ford (1976) and Ronald Reagan (1982);  Similarity score: 0.628917
# 22: William J. Clinton (1993) and Barack Obama (2009);  Similarity score: 0.627454
# 23: Theodore Roosevelt (1907) and William Howard Taft (1910);  Similarity score: 0.626985
# 24: William J. Clinton (1994) and Barack Obama (2012);  Similarity score: 0.625587
# 25: Chester A. Arthur (1881) and Grover Cleveland (1894);  Similarity score: 0.625151
# 26: Benjamin Harrison (1892) and Grover Cleveland (1894);  Similarity score: 0.623968
# 27: Benjamin Harrison (1891) and Grover Cleveland (1894);  Similarity score: 0.623924
# 28: William J. Clinton (1994) and Barack Obama (2013);  Similarity score: 0.621445
# 29: Gerald R. Ford (1975) and Jimmy Carter (1981);  Similarity score: 0.621202
# 30: William McKinley (1899) and William Howard Taft (1912);  Similarity score: 0.620666
# 31: George Bush (1992) and William J. Clinton (1993);  Similarity score: 0.617294
# 32: William J. Clinton (1998) and Barack Obama (2011);  Similarity score: 0.616600
# 33: Benjamin Harrison (1891) and Grover Cleveland (1893);  Similarity score: 0.612775
# 34: William J. Clinton (1993) and Barack Obama (2012);  Similarity score: 0.608534
# 35: Chester A. Arthur (1884) and Grover Cleveland (1885);  Similarity score: 0.608145
# 36: William J. Clinton (2000) and George W. Bush (2004);  Similarity score: 0.606465
# 37: William J. Clinton (1995) and Barack Obama (2011);  Similarity score: 0.605172
# 38: Theodore Roosevelt (1903) and William Howard Taft (1912);  Similarity score: 0.604007
# 39: Chester A. Arthur (1881) and Grover Cleveland (1888);  Similarity score: 0.603627
# 40: Rutherford B. Hayes (1880) and Benjamin Harrison (1891);  Similarity score: 0.602613
# 41: Gerald R. Ford (1975) and Ronald Reagan (1981);  Similarity score: 0.601390
# 42: Gerald R. Ford (1977) and Jimmy Carter (1981);  Similarity score: 0.601345
# 43: John F. Kennedy (1962) and Jimmy Carter (1981);  Similarity score: 0.601135
# 44: Chester A. Arthur (1881) and Grover Cleveland (1886);  Similarity score: 0.600492
# 45: Zachary Taylor (1849) and Millard Fillmore (1851);  Similarity score: 0.599937
# 46: William J. Clinton (1993) and Barack Obama (2013);  Similarity score: 0.599428
# 47: Rutherford B. Hayes (1877) and Benjamin Harrison (1889);  Similarity score: 0.599321
# 48: Theodore Roosevelt (1903) and William Howard Taft (1910);  Similarity score: 0.598649
# 49: William J. Clinton (1994) and Barack Obama (2009);  Similarity score: 0.598403
# 50: William J. Clinton (1995) and Barack Obama (2012);  Similarity score: 0.597765

# %%
print("Top 50 most similar pairs of SOUs given by the same President:")
for k in range(50):
    sim, i, j = same_pres_sort[k]
    print("%d:" % (k+1), "%s:" % presidents[i], "%d and" % int(years[i])
          , "%d; " % int(years[j]), "Similarity score: %f" % sim)
# Out:
# Top 50 most similar pairs of SOUs given by the same President:
# 1: Barack Obama: 2012 and 2013;  Similarity score: 0.985640
# 2: William McKinley: 1899 and 1900;  Similarity score: 0.754864
# 3: William J. Clinton: 1997 and 1998;  Similarity score: 0.751195
# 4: William J. Clinton: 1998 and 2000;  Similarity score: 0.750868
# 5: William J. Clinton: 1998 and 1999;  Similarity score: 0.748687
# 6: William J. Clinton: 1994 and 1995;  Similarity score: 0.742226
# 7: William Howard Taft: 1910 and 1912;  Similarity score: 0.741289
# 8: Barack Obama: 2010 and 2012;  Similarity score: 0.739157
# 9: Barack Obama: 2011 and 2012;  Similarity score: 0.737905
# 10: William J. Clinton: 1999 and 2000;  Similarity score: 0.736413
# 11: Barack Obama: 2010 and 2013;  Similarity score: 0.730633
# 12: Dwight D. Eisenhower: 1955 and 1956;  Similarity score: 0.726676
# 13: Barack Obama: 2011 and 2013;  Similarity score: 0.722149
# 14: Barack Obama: 2009 and 2010;  Similarity score: 0.720039
# 15: Theodore Roosevelt: 1905 and 1907;  Similarity score: 0.717474
# 16: James K. Polk: 1845 and 1846;  Similarity score: 0.716529
# 17: William McKinley: 1898 and 1899;  Similarity score: 0.716090
# 18: Grover Cleveland: 1894 and 1896;  Similarity score: 0.708378
# 19: Theodore Roosevelt: 1906 and 1907;  Similarity score: 0.703074
# 20: William Howard Taft: 1909 and 1910;  Similarity score: 0.702538
# 21: William J. Clinton: 1997 and 1999;  Similarity score: 0.700661
# 22: Ronald Reagan: 1981 and 1982;  Similarity score: 0.695909
# 23: Theodore Roosevelt: 1907 and 1908;  Similarity score: 0.690150
# 24: Andrew Jackson: 1834 and 1835;  Similarity score: 0.689824
# 25: Theodore Roosevelt: 1901 and 1905;  Similarity score: 0.689190
# 26: Barack Obama: 2010 and 2011;  Similarity score: 0.689141
# 27: James Buchanan: 1858 and 1859;  Similarity score: 0.685617
# 28: Theodore Roosevelt: 1904 and 1905;  Similarity score: 0.684676
# 29: Grover Cleveland: 1893 and 1894;  Similarity score: 0.684568
# 30: William Howard Taft: 1909 and 1912;  Similarity score: 0.684434
# 31: Rutherford B. Hayes: 1879 and 1880;  Similarity score: 0.681630
# 32: Grover Cleveland: 1885 and 1886;  Similarity score: 0.681137
# 33: James K. Polk: 1846 and 1847;  Similarity score: 0.680659
# 34: Grover Cleveland: 1886 and 1888;  Similarity score: 0.677599
# 35: William J. Clinton: 1997 and 2000;  Similarity score: 0.676637
# 36: Dwight D. Eisenhower: 1954 and 1956;  Similarity score: 0.675988
# 37: William Howard Taft: 1911 and 1912;  Similarity score: 0.675027
# 38: Dwight D. Eisenhower: 1954 and 1955;  Similarity score: 0.674816
# 39: William Howard Taft: 1910 and 1911;  Similarity score: 0.672394
# 40: Theodore Roosevelt: 1905 and 1906;  Similarity score: 0.669029
# 41: Theodore Roosevelt: 1904 and 1907;  Similarity score: 0.668439
# 42: Chester A. Arthur: 1881 and 1882;  Similarity score: 0.666491
# 43: William J. Clinton: 1996 and 1997;  Similarity score: 0.666269
# 44: William McKinley: 1897 and 1898;  Similarity score: 0.664931
# 45: Theodore Roosevelt: 1901 and 1907;  Similarity score: 0.660166
# 46: William J. Clinton: 1995 and 1998;  Similarity score: 0.658622
# 47: Benjamin Harrison: 1891 and 1892;  Similarity score: 0.656416
# 48: Theodore Roosevelt: 1901 and 1902;  Similarity score: 0.656030
# 49: Ronald Reagan: 1982 and 1983;  Similarity score: 0.654319
# 50: William J. Clinton: 1993 and 1994;  Similarity score: 0.651851

# %%
# make a dictionnary with each pair, 
# and all the similarity scores between their speeches,
# then take the mean for each
named_diff_pres = [(tuple(sorted((presidents[i], presidents[j]))), sim) \
                       for sim, i, j in diff_pres_sort]
means = {}
for pair, sim in named_diff_pres:
    if pair not in means.keys():
        means[pair] = [sim]
    else:
        means[pair].append(sim)
means = [(pair, np.mean(sim)) for pair, sim in means.items()]
means = sorted(means, key=lambda x: x[1], reverse=True)

# %%
print("Top 25 most similar pairs of Presidents:")
for k in range(25):
    pair, sim = means[k]
    print("%d:" % (k+1), "%s:" % pair[0], "and %s;" % pair[1]
          , "Similarity score: %f" % sim)
# Out:
# Top 25 most similar pairs of Presidents:
# 1: Millard Fillmore: and Zachary Taylor; Similarity score: 0.560071
# 2: Barack Obama: and William J. Clinton; Similarity score: 0.558363
# 3: Benjamin Harrison: and Rutherford B. Hayes; Similarity score: 0.544537
# 4: Chester A. Arthur: and Rutherford B. Hayes; Similarity score: 0.540669
# 5: Benjamin Harrison: and Chester A. Arthur; Similarity score: 0.539790
# 6: Theodore Roosevelt: and William Howard Taft; Similarity score: 0.526337
# 7: Benjamin Harrison: and Grover Cleveland; Similarity score: 0.518406
# 8: Benjamin Harrison: and William Howard Taft; Similarity score: 0.516884
# 9: Chester A. Arthur: and William Howard Taft; Similarity score: 0.516318
# 10: George Bush: and William J. Clinton; Similarity score: 0.515797
# 11: Grover Cleveland: and Rutherford B. Hayes; Similarity score: 0.510615
# 12: William Howard Taft: and William McKinley; Similarity score: 0.504355
# 13: Andrew Jackson: and Martin Van Buren; Similarity score: 0.502953
# 14: Gerald R. Ford: and Jimmy Carter; Similarity score: 0.500977
# 15: George W. Bush: and William J. Clinton; Similarity score: 0.500602
# 16: Chester A. Arthur: and Grover Cleveland; Similarity score: 0.497961
# 17: James Buchanan: and Zachary Taylor; Similarity score: 0.494409
# 18: James K. Polk: and Millard Fillmore; Similarity score: 0.492707
# 19: James Buchanan: and Millard Fillmore; Similarity score: 0.488751
# 20: Franklin Pierce: and James Buchanan; Similarity score: 0.485333
# 21: Ulysses S. Grant: and William McKinley; Similarity score: 0.484608
# 22: Ronald Reagan: and William J. Clinton; Similarity score: 0.483964
# 23: Franklin Pierce: and Millard Fillmore; Similarity score: 0.483629
# 24: Rutherford B. Hayes: and William Howard Taft; Similarity score: 0.483391
# 25: Chester A. Arthur: and William McKinley; Similarity score: 0.482167

# %% [markdown]
# ### (c)

# %%
nc = 12
model = KMeans(n_clusters = nc, n_jobs = -1, max_iter=50)
sou_clust = model.fit(tf_idf)
labels = model.predict(tf_idf)
cl_len = np.zeros(nc)
for i in range(nc):
    print("Cluster %d" % (i+1))
    for c in np.where(labels==i)[0]:
        cl_len[i] += 1
        print(presidents[c], years[c])
print(cl_len)
print("Average cluster length = %f" % np.mean(cl_len))
# Out:
# Cluster 1
# Grover Cleveland 1885
# Grover Cleveland 1894
# Grover Cleveland 1896
# William McKinley 1898
# William McKinley 1899
# William McKinley 1900
# Cluster 2
# George Washington 1790
# George Washington 1791
# George Washington 1792
# George Washington 1793
# George Washington 1794
# George Washington 1795
# George Washington 1796
# John Adams 1797
# John Adams 1798
# John Adams 1799
# John Adams 1800
# Thomas Jefferson 1801
# Thomas Jefferson 1802
# Thomas Jefferson 1803
# Thomas Jefferson 1804
# Thomas Jefferson 1805
# Thomas Jefferson 1806
# Thomas Jefferson 1807
# Thomas Jefferson 1808
# James Madison 1809
# James Madison 1810
# James Madison 1811
# James Madison 1812
# James Madison 1813
# James Madison 1814
# James Madison 1815
# James Madison 1816
# James Monroe 1817
# James Monroe 1818
# James Monroe 1819
# James Monroe 1820
# James Monroe 1821
# James Monroe 1822
# James Monroe 1823
# James Monroe 1824
# John Quincy Adams 1825
# John Quincy Adams 1826
# John Quincy Adams 1827
# John Quincy Adams 1828
# Andrew Jackson 1831
# Andrew Jackson 1832
# Andrew Jackson 1833
# John Tyler 1841
# Zachary Taylor 1849
# Millard Fillmore 1850
# Abraham Lincoln 1861
# Abraham Lincoln 1862
# Abraham Lincoln 1863
# Abraham Lincoln 1864
# Andrew Johnson 1865
# Andrew Johnson 1866
# Ulysses S. Grant 1869
# Ulysses S. Grant 1870
# Ulysses S. Grant 1871
# Ulysses S. Grant 1876
# Grover Cleveland 1887
# Theodore Roosevelt 1902
# Woodrow Wilson 1913
# Woodrow Wilson 1914
# Woodrow Wilson 1915
# Woodrow Wilson 1916
# Woodrow Wilson 1917
# Woodrow Wilson 1918
# Woodrow Wilson 1919
# Woodrow Wilson 1920
# Warren G. Harding 1921
# Warren G. Harding 1922
# Calvin Coolidge 1923
# Calvin Coolidge 1924
# Calvin Coolidge 1925
# Calvin Coolidge 1926
# Calvin Coolidge 1927
# Calvin Coolidge 1928
# Herbert Hoover 1930
# Herbert Hoover 1931
# Herbert Hoover 1932
# Franklin D. Roosevelt 1934
# Franklin D. Roosevelt 1935
# Franklin D. Roosevelt 1936
# Franklin D. Roosevelt 1937
# Franklin D. Roosevelt 1940
# Franklin D. Roosevelt 1941
# Franklin D. Roosevelt 1942
# Franklin D. Roosevelt 1944
# Richard M. Nixon 1973
# Cluster 3
# Franklin D. Roosevelt 1938
# Franklin D. Roosevelt 1939
# Franklin D. Roosevelt 1943
# Franklin D. Roosevelt 1945
# Harry S Truman 1947
# Harry S Truman 1948
# Harry S Truman 1949
# Harry S Truman 1950
# Harry S Truman 1951
# Harry S Truman 1952
# Harry S Truman 1953
# Dwight D. Eisenhower 1953
# Dwight D. Eisenhower 1954
# Dwight D. Eisenhower 1955
# Dwight D. Eisenhower 1956
# Dwight D. Eisenhower 1957
# Dwight D. Eisenhower 1958
# Dwight D. Eisenhower 1959
# Dwight D. Eisenhower 1960
# Dwight D. Eisenhower 1961
# John F. Kennedy 1961
# John F. Kennedy 1962
# John F. Kennedy 1963
# Lyndon B. Johnson 1964
# Lyndon B. Johnson 1965
# Lyndon B. Johnson 1966
# Lyndon B. Johnson 1967
# Lyndon B. Johnson 1968
# Lyndon B. Johnson 1969
# Richard M. Nixon 1970
# Richard M. Nixon 1971
# Richard M. Nixon 1972
# Richard M. Nixon 1974
# Gerald R. Ford 1975
# Gerald R. Ford 1976
# Gerald R. Ford 1977
# Jimmy Carter 1978
# Jimmy Carter 1979
# Jimmy Carter 1980
# Ronald Reagan 1981
# Ronald Reagan 1982
# Ronald Reagan 1983
# Ronald Reagan 1984
# Ronald Reagan 1985
# Ronald Reagan 1986
# Ronald Reagan 1987
# Ronald Reagan 1988
# George Bush 1989
# George Bush 1990
# George Bush 1991
# George Bush 1992
# George W. Bush 2001
# George W. Bush 2002
# George W. Bush 2003
# George W. Bush 2004
# George W. Bush 2005
# George W. Bush 2006
# George W. Bush 2007
# George W. Bush 2008
# Cluster 4
# Jimmy Carter 1981
# Cluster 5
# James K. Polk 1846
# Cluster 6
# William Howard Taft 1910
# William Howard Taft 1911
# William Howard Taft 1912
# Cluster 7
# Harry S Truman 1946
# Cluster 8
# Andrew Jackson 1829
# Andrew Jackson 1830
# Andrew Jackson 1834
# Andrew Jackson 1835
# Andrew Jackson 1836
# Martin Van Buren 1837
# Martin Van Buren 1838
# Martin Van Buren 1839
# Martin Van Buren 1840
# John Tyler 1842
# John Tyler 1843
# John Tyler 1844
# James K. Polk 1845
# James K. Polk 1847
# James K. Polk 1848
# Millard Fillmore 1851
# Millard Fillmore 1852
# Franklin Pierce 1853
# Franklin Pierce 1854
# Franklin Pierce 1855
# Franklin Pierce 1856
# James Buchanan 1857
# James Buchanan 1858
# James Buchanan 1859
# James Buchanan 1860
# Andrew Johnson 1867
# Cluster 9
# Andrew Johnson 1868
# Ulysses S. Grant 1872
# Ulysses S. Grant 1873
# Ulysses S. Grant 1874
# Ulysses S. Grant 1875
# Rutherford B. Hayes 1877
# Rutherford B. Hayes 1878
# Rutherford B. Hayes 1879
# Rutherford B. Hayes 1880
# Chester A. Arthur 1881
# Chester A. Arthur 1882
# Chester A. Arthur 1883
# Chester A. Arthur 1884
# Grover Cleveland 1886
# Grover Cleveland 1888
# Benjamin Harrison 1889
# Benjamin Harrison 1890
# Benjamin Harrison 1891
# Benjamin Harrison 1892
# Grover Cleveland 1893
# William McKinley 1897
# Theodore Roosevelt 1903
# William Howard Taft 1909
# Herbert Hoover 1929
# Cluster 10
# Grover Cleveland 1895
# Cluster 11
# Theodore Roosevelt 1901
# Theodore Roosevelt 1904
# Theodore Roosevelt 1905
# Theodore Roosevelt 1906
# Theodore Roosevelt 1907
# Theodore Roosevelt 1908
# Cluster 12
# William J. Clinton 1993
# William J. Clinton 1994
# William J. Clinton 1995
# William J. Clinton 1996
# William J. Clinton 1997
# William J. Clinton 1998
# William J. Clinton 1999
# William J. Clinton 2000
# Barack Obama 2009
# Barack Obama 2010
# Barack Obama 2011
# Barack Obama 2012
# Barack Obama 2013
# [ 6. 85. 59.  1.  1.  3.  1. 26. 24.  1.  6. 13.]
# Average cluster length = 18.833333

# %% [markdown]
# After choosing several sizes of clusters, I thought that 12 was a great option because although it allows 4 clusters of length 1, it allows us to see interesting trends. For instance, we can see in this last cluster only contains Obama and Bill J. Clinton speeches, and these two correspond to the top 2 most similar pair of presidents! Each cluster combines speeches with others using the distance between each tf-idf vector, which allows a clustering of the similar speeches in order to compare them.
